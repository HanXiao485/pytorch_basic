# %%
import torch
import random
from d2l import torch as d2l

# %%
def synthetic_data(w,b,num_examples):
    """linear+noise"""
    X = torch.normal(0,1,(num_examples,len(w)))
    y = torch.matmul(X,w)+b
    y += torch.normal(0,0.01,y.shape)#noise
    return X,y.reshape((-1,1))

# %%
true_w = torch.tensor([2,-3.4])
true_b = 4.2
features,labels = synthetic_data(true_w,true_b,1000)

# %%
print(features[0],labels[0])
# Out:
# tensor([0.8479, 0.8654]) tensor([2.9517])

# %%
d2l.set_figsize()
d2l.plt.scatter(features[:,(1)].detach().numpy(),labels.detach().numpy(),0.25)

# %%
def data_iter(batch_size, features, labels):
    num_examples = len(features)
    indices = list(range(num_examples))
    random.shuffle(indices)
    for i in range(0, num_examples, batch_size):
        batch_indices = torch.tensor(
            indices[i:min(i+batch_size,num_examples)]
        )
        yield features[batch_indices],labels[batch_indices]

# %%
batch_size = 10

for X,y in data_iter(batch_size, features, labels):
    print(X,'\n',y)
    break
# Out:
# tensor([[-1.7150, -0.0907],
#         [ 1.3242,  0.7135],
#         [ 1.0723,  0.2527],
#         [-1.2631,  0.5855],
#         [-0.1041, -0.1382],
#         [ 0.7224, -0.5588],
#         [ 0.3545, -0.5359],
#         [-1.5224,  0.1140],
#         [-1.8202, -0.6505],
#         [-0.3344, -0.4431]])
#  tensor([[ 1.0881],
#         [ 4.4287],
#         [ 5.4889],
#         [-0.3265],
#         [ 4.4530],
#         [ 7.5691],
#         [ 6.7137],
#         [ 0.7852],
#         [ 2.7727],
#         [ 5.0370]])

# %%
w = torch.normal(0,0.01,size=(2,1),requires_grad=True)
b = torch.zeros(1,requires_grad=True)

# %%
def linreg(X,w,b):
    """linearRegression"""
    return torch.matmul(X,w)+b

# %%
def squared_loss(y_hat,y):
    """lossFunction"""
    return (y_hat-y.reshape(y_hat.shape))**2/2    #.shape()

# %%
def sgd(params,lr,batch_size):
    """SGD"""
    with torch.no_grad():
        for param in params:
            param -= lr*param.grad/batch_size    #.grad()
            param.grad.zero_()

# %%
lr = 0.03
num_epochs = 3
net = linreg
loss = squared_loss

# %%
for epoch in range(num_epochs):
    for X,y in data_iter(batch_size, features, labels):
        l = loss(net(X,w,b),y)
        l.sum().backward()
        sgd([w,b],lr,batch_size)
    with torch.no_grad():
        train_l = loss(net(features, w, b), labels)
        print(f'epoch{epoch+1}, loss:{float(train_l.mean())}')    #:f
# Out:
# epoch1, loss:0.05055781081318855
# epoch2, loss:0.00022914203873369843
# epoch3, loss:5.39797474630177e-05

# %%
print(f'w估计误差：{true_w-w.reshape(true_w.shape)}')
print(f'b估计误差：{true_b-b}')
# Out:
# w估计误差：tensor([-0.0006, -0.0011], grad_fn=<SubBackward0>)
# b估计误差：tensor([0.0012], grad_fn=<RsubBackward1>)
